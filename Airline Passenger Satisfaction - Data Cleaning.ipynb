# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
missing_values = ['-','/',' ','nan','nul','null','Nul','Null']
data = pd.read_csv('airline_passenger_satisfaction.csv')

# %%
data.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
df = data.copy()

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Gender', 'Age', 'Customer Type', 'Type of Travel', 'Class',
#        'Flight Distance', 'Departure Delay', 'Arrival Delay',
#        'Departure and Arrival Time Convenience', 'Ease of Online Booking',
#        'Check-in Service', 'Online Boarding', 'Gate Location',
#        'On-board Service', 'Seat Comfort', 'Leg Room Service', 'Cleanliness',
#        'Food and Drink', 'In-flight Service', 'In-flight Wifi Service',
#        'In-flight Entertainment', 'Baggage Handling', 'Satisfaction'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# ...

# %%
df.isnull().sum()/len(df.isnull().sum())
# Out:
# ID                                         0.000
# Gender                                     0.000
# Age                                        0.000
# Customer Type                              0.000
# Type of Travel                             0.000
# Class                                      0.000
# Flight Distance                            0.000
# Departure Delay                            0.000
# Arrival Delay                             16.375
# Departure and Arrival Time Convenience     0.000
# Ease of Online Booking                     0.000
# Check-in Service                           0.000
# Online Boarding                            0.000
# Gate Location                              0.000
# On-board Service                           0.000
# Seat Comfort                               0.000
# Leg Room Service                           0.000
# Cleanliness                                0.000
# Food and Drink                             0.000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                                            count          mean           std  \
# ID                                      129880.0  64940.500000  37493.270818
# Age                                     129880.0     39.427957     15.119360
# Flight Distance                         129880.0   1190.316392    997.452477
# Departure Delay                         129880.0     14.713713     38.071126
# Arrival Delay                           129487.0     15.091129     38.465650
# Departure and Arrival Time Convenience  129880.0      3.057599      1.526741
# Ease of Online Booking                  129880.0      2.756876      1.401740
# Check-in Service                        129880.0      3.306267      1.266185
# Online Boarding                         129880.0      3.252633      1.350719
# Gate Location                           129880.0      2.976925      1.278520
# On-board Service                        129880.0      3.383023      1.287099
# ...

# %%
df.ID.count()
# Out:
# 129880

# %%
plt.boxplot(df.Age)
plt.title('Age')
plt.show()

# %%
df.Age.hist(bins=10,color='midnightblue',edgecolor='Black')
plt.title('Age')
plt.xlabel('Age')
plt.ylabel('Number of passengers')
plt.grid(False)
plt.show()

# %%
plt.boxplot(df['Flight Distance'])
plt.title('Flight Distance (Miles)')
plt.show()

# %%
df['Flight Distance'].hist(bins=10,color='midnightblue',edgecolor='Black')
plt.title('Flight Distance')
plt.xlabel('Flight Distance (Miles)')
plt.ylabel('Number of passengers')
plt.grid(False)
plt.show()

# %%
plt.boxplot(df['Departure Delay'])
plt.title('Departure Delay (Minutes)')
plt.show()

# %%
df['Departure Delay'].hist(bins=10,color='midnightblue',edgecolor='Black')
plt.title('Departure Delay')
plt.xlabel('Departure Delay (Minutes)')
plt.ylabel('Number of passengers')
plt.grid(False)
plt.show()

# %%
plt.boxplot(df['Arrival Delay'])
plt.title('Arrival Delay (Minutes)')
plt.show()

# %%
df['Arrival Delay'].hist(bins=10,color='midnightblue',edgecolor='Black')
plt.xlabel('Arrival Delay (Minutes)')
plt.ylabel('Number of passengers')
plt.title('Arrival Delay')
plt.grid(False)
plt.show()

# %%
import sqlite3
conn = sqlite3.connect('passengers.db')
c = conn.cursor()

# %%
passengers = pd.read_csv('airline_passenger_satisfaction.csv')

# %%
passengers.to_sql('passengers', conn, if_exists='append', index = False)
# Out:
# C:\Users\utente\anaconda3\envs\Projects\lib\site-packages\pandas\core\generic.py:2882: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,
